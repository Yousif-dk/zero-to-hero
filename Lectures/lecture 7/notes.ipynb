# %% [markdown]
# #### Notes

# %% [markdown]
# After implementing the multiple blocks, our shit is actually kinda big. To make this more stable, we use residual connections

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We fork off the residual path, do all our shit, & fork back into it with addition.
